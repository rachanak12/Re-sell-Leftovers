# %% [markdown]
# # Data Mining

# %% [markdown]
# In this project, I used the Google Trends API to retrieve data for the past 7 days, including November 11. This allowed me to analyze search trends and extract valuable insights into user behavior and interests over this specific time period.

# %%
pip install pytrends

# %%
keywords = [
    "pizza", "burger", "sushi", "pasta", "salad", "steak", "tacos", "sandwich", "noodles", "omelette",
    "burrito", "risotto", "dumplings", "ravioli", "lasagna", "paella", "curry", "falafel", "quiche", "wrap",
    "gyros", "shawarma", "bruschetta", "calzone", "fajitas", "enchiladas", "gnocchi", "meatballs", "wings", "pancakes",
    "waffles", "crepes", "donuts", "tiramisu", "cheesecake", "brownie", "bread", "apple", "banana", "orange", "grape", "strawberry", "blueberry", "pineapple", "kiwi", "mango", "pear",
        "bread", "milk", "eggs", "butter", "cheese",
    "yogurt", "chicken", "beef", "pork", "fish",
    "rice", "pasta", "vegetables", "fruits", "cereal",
    "sugar", "salt", "pepper", "olive oil", "vinegar"
]

# %%
import pandas as pd
all_data = pd.DataFrame()

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)
for i in range(0, len(keywords), 4):
    keyword_group = keywords[i:i+4]
    pytrends.build_payload(keyword_group, timeframe='now 7-d')
    df = pytrends.interest_over_time()
    all_data = pd.concat([all_data, df], axis=1)
print(all_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# ...

# %%
all_data.head()
# Out:
#                      pizza  burger  sushi  pasta  isPartial  salad  steak  \
# date
# 2024-11-04 07:00:00     14       5      5      7      False     23     18
# 2024-11-04 08:00:00     14       6      5      8      False     19     17
# 2024-11-04 09:00:00     14       6      5      9      False     18     17
# 2024-11-04 10:00:00     17       7      7     10      False     18     17
# 2024-11-04 11:00:00     17       8      7     11      False     20     19
#
#                      tacos  sandwich  isPartial  ...  isPartial  fruits  \
# date                                             ...
# 2024-11-04 07:00:00      6        13      False  ...      False      21
# 2024-11-04 08:00:00      5        13      False  ...      False      22
# 2024-11-04 09:00:00      5        14      False  ...      False      20
# 2024-11-04 10:00:00      7        15      False  ...      False      21
# 2024-11-04 11:00:00      8        16      False  ...      False      22
#
# ...

# %%
all_data.isnull().sum()
# Out:
# pizza        0
# burger       0
# sushi        0
# pasta        0
# isPartial    0
#             ..
# isPartial    0
# pepper       0
# olive oil    0
# vinegar      0
# isPartial    0
# Length: 84, dtype: int64

# %%
all_data.tail()
# Out:
#                      pizza  burger  sushi  pasta  isPartial  salad  steak  \
# date
# 2024-11-11 03:00:00     27       9      9      8      False     38     41
# 2024-11-11 04:00:00     23       8      7      7      False     34     34
# 2024-11-11 05:00:00     19       7      6      7      False     29     26
# 2024-11-11 06:00:00     15       6      5      7      False     24     19
# 2024-11-11 07:00:00     15       6      4      7       True     22     19
#
#                      tacos  sandwich  isPartial  ...  isPartial  fruits  \
# date                                             ...
# 2024-11-11 03:00:00     23        22      False  ...      False      25
# 2024-11-11 04:00:00     18        20      False  ...      False      25
# 2024-11-11 05:00:00     14        17      False  ...      False      30
# 2024-11-11 06:00:00      9        13      False  ...      False      24
# 2024-11-11 07:00:00      7        14       True  ...       True      21
#
# ...

# %%
all_data = all_data.loc[:, ~all_data.columns.str.startswith('isPartial')]

# %%
all_data['total'] = all_data.sum(axis=1)
# Out:
# <ipython-input-9-16cf6c2396a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['total'] = all_data.sum(axis=1)

# %%
all_data.reset_index(drop=False, inplace=True)

# %%
all_data
# Out:
#                    date  pizza  burger  sushi  pasta  salad  steak  tacos  \
# 0   2024-11-04 07:00:00     14       5      5      7     23     18      6
# 1   2024-11-04 08:00:00     14       6      5      8     19     17      5
# 2   2024-11-04 09:00:00     14       6      5      9     18     17      5
# 3   2024-11-04 10:00:00     17       7      7     10     18     17      7
# 4   2024-11-04 11:00:00     17       8      7     11     20     19      8
# ..                  ...    ...     ...    ...    ...    ...    ...    ...
# 164 2024-11-11 03:00:00     27       9      9      8     38     41     23
# 165 2024-11-11 04:00:00     23       8      7      7     34     34     18
# 166 2024-11-11 05:00:00     19       7      6      7     29     26     14
# 167 2024-11-11 06:00:00     15       6      5      7     24     19      9
# 168 2024-11-11 07:00:00     15       6      4      7     22     19      7
#
#      sandwich  noodles  ...  pasta  vegetables  fruits  cereal  sugar  salt  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
all_data['hour'] = all_data['date'].dt.hour

plt.figure(figsize=(8, 5))
plt.plot(all_data['hour'], all_data['total'], marker='o', color='blue', label='Total')
plt.title('Total Value Distribution by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Total')
plt.axhline(y=all_data['total'].mean(), color='red', linestyle='--', label='Mean Total')
plt.legend()
plt.grid()
plt.xticks(all_data['hour'])
plt.show()

# %%
all_data["date"]=pd.to_datetime(all_data["date"])
all_data['is_holiday'] = all_data['date'].dt.strftime('%m-%d').isin(['11-09', '11-10']).astype(int)

# %%
all_data.to_csv('all_data_nov_11.csv', index=False)

# %%
all_data
# Out:
#                    date  pizza  burger  sushi  pasta  salad  steak  tacos  \
# 0   2024-11-04 07:00:00     14       5      5      7     23     18      6
# 1   2024-11-04 08:00:00     14       6      5      8     19     17      5
# 2   2024-11-04 09:00:00     14       6      5      9     18     17      5
# 3   2024-11-04 10:00:00     17       7      7     10     18     17      7
# 4   2024-11-04 11:00:00     17       8      7     11     20     19      8
# ..                  ...    ...     ...    ...    ...    ...    ...    ...
# 164 2024-11-11 03:00:00     27       9      9      8     38     41     23
# 165 2024-11-11 04:00:00     23       8      7      7     34     34     18
# 166 2024-11-11 05:00:00     19       7      6      7     29     26     14
# 167 2024-11-11 06:00:00     15       6      5      7     24     19      9
# 168 2024-11-11 07:00:00     15       6      4      7     22     19      7
#
#      sandwich  noodles  ...  fruits  cereal  sugar  salt  pepper  olive oil  \
# ...
