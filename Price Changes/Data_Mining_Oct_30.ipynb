# %% [markdown]
# # Data Mining

# %% [markdown]
# In this project, I used the Google Trends API to retrieve data for the past 7 days, including October 30. This allowed me to analyze search trends and extract valuable insights into user behavior and interests over this specific time period.

# %%
pip install pytrends
# Out:
# Requirement already satisfied: pytrends in /usr/local/lib/python3.10/dist-packages (4.9.2)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.10/dist-packages (from pytrends) (2.32.3)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from pytrends) (2.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pytrends) (4.9.4)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->pytrends) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pytrends) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.16.0)

# %%
keywords = [
    "pizza", "burger", "sushi", "pasta", "salad", "steak", "tacos", "sandwich", "noodles", "omelette",
    "burrito", "risotto", "dumplings", "ravioli", "lasagna", "paella", "curry", "falafel", "quiche", "wrap",
    "gyros", "shawarma", "bruschetta", "calzone", "fajitas", "enchiladas", "gnocchi", "meatballs", "wings", "pancakes",
    "waffles", "crepes", "donuts", "tiramisu", "cheesecake", "brownie", "bread", "apple", "banana", "orange", "grape", "strawberry", "blueberry", "pineapple", "kiwi", "mango", "pear",
        "bread", "milk", "eggs", "butter", "cheese",
    "yogurt", "chicken", "beef", "pork", "fish",
    "rice", "pasta", "vegetables", "fruits", "cereal",
    "sugar", "salt", "pepper", "olive oil", "vinegar"
]

# %%
import pandas as pd
all_data = pd.DataFrame()

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)
for i in range(0, len(keywords), 4):
    keyword_group = keywords[i:i+4]
    pytrends.build_payload(keyword_group, timeframe='now 7-d')
    df = pytrends.interest_over_time()
    all_data = pd.concat([all_data, df], axis=1)
print(all_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
#                      pizza  burger  sushi  pasta  isPartial  salad  steak  \
# date
# 2024-10-23 19:00:00     35      11      9     11      False     41     43
# 2024-10-23 20:00:00     37      11     10     12      False     46     49
# 2024-10-23 21:00:00     52      12     12     14      False     56     69
# 2024-10-23 22:00:00     59      14     15     15      False     65     85
# 2024-10-23 23:00:00     54      14     14     14      False     60     89
# ...                    ...     ...    ...    ...        ...    ...    ...
# 2024-10-30 15:00:00     32      10     10     12      False     36     34
# 2024-10-30 16:00:00     38      12     11     14      False     42     37
# 2024-10-30 17:00:00     41      12     12     15      False     43     42
# 2024-10-30 18:00:00     41      12     12     15      False     42     42
# 2024-10-30 19:00:00     39      12     12     13       True     42     42
#
#                      tacos  sandwich  isPartial  ...  isPartial  fruits  \
# date                                             ...
# 2024-10-23 19:00:00     26        29      False  ...      False      20
# 2024-10-23 20:00:00     28        31      False  ...      False      22
# 2024-10-23 21:00:00     35        35      False  ...      False      24
# 2024-10-23 22:00:00     41        38      False  ...      False      26
# 2024-10-23 23:00:00     43        37      False  ...      False      27
# ...                    ...       ...        ...  ...        ...     ...
# 2024-10-30 15:00:00     22        30      False  ...      False      25
# 2024-10-30 16:00:00     25        34      False  ...      False      25
# 2024-10-30 17:00:00     28        33      False  ...      False      23
# 2024-10-30 18:00:00     29        30      False  ...      False      23
# 2024-10-30 19:00:00     28        33       True  ...       True      21
#
#                      cereal  sugar  salt  isPartial  pepper  olive oil  \
# date
# 2024-10-23 19:00:00       8     74    50      False      64         20
# 2024-10-23 20:00:00      10     77    53      False      72         23
# 2024-10-23 21:00:00      11     84    60      False      82         28
# 2024-10-23 22:00:00      11     91    65      False      89         33
# 2024-10-23 23:00:00      13     96    63      False      89         34
# ...                     ...    ...   ...        ...     ...        ...
# 2024-10-30 15:00:00       7     71    48      False      61         19
# 2024-10-30 16:00:00       8     74    46      False      74         21
# 2024-10-30 17:00:00       8     79    51      False      77         21
# 2024-10-30 18:00:00       8     81    52      False      78         21
# 2024-10-30 19:00:00       9     80    55       True      82         28
#
#                      vinegar  isPartial
# date
# 2024-10-23 19:00:00       35      False
# 2024-10-23 20:00:00       40      False
# 2024-10-23 21:00:00       47      False
# 2024-10-23 22:00:00       54      False
# 2024-10-23 23:00:00       53      False
# ...                      ...        ...
# 2024-10-30 15:00:00       30      False
# 2024-10-30 16:00:00       34      False
# 2024-10-30 17:00:00       37      False
# 2024-10-30 18:00:00       35      False
# 2024-10-30 19:00:00       35       True
#
# [169 rows x 84 columns]
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %%
all_data.head()
# Out:
#                      pizza  burger  sushi  pasta  isPartial  salad  steak  \
# date
# 2024-10-23 19:00:00     35      11      9     11      False     41     43
# 2024-10-23 20:00:00     37      11     10     12      False     46     49
# 2024-10-23 21:00:00     52      12     12     14      False     56     69
# 2024-10-23 22:00:00     59      14     15     15      False     65     85
# 2024-10-23 23:00:00     54      14     14     14      False     60     89
#
#                      tacos  sandwich  isPartial  ...  isPartial  fruits  \
# date                                             ...
# 2024-10-23 19:00:00     26        29      False  ...      False      20
# 2024-10-23 20:00:00     28        31      False  ...      False      22
# 2024-10-23 21:00:00     35        35      False  ...      False      24
# 2024-10-23 22:00:00     41        38      False  ...      False      26
# 2024-10-23 23:00:00     43        37      False  ...      False      27
#
#                      cereal  sugar  salt  isPartial  pepper  olive oil  \
# date
# 2024-10-23 19:00:00       8     74    50      False      64         20
# 2024-10-23 20:00:00      10     77    53      False      72         23
# 2024-10-23 21:00:00      11     84    60      False      82         28
# 2024-10-23 22:00:00      11     91    65      False      89         33
# 2024-10-23 23:00:00      13     96    63      False      89         34
#
#                      vinegar  isPartial
# date
# 2024-10-23 19:00:00       35      False
# 2024-10-23 20:00:00       40      False
# 2024-10-23 21:00:00       47      False
# 2024-10-23 22:00:00       54      False
# 2024-10-23 23:00:00       53      False
#
# [5 rows x 84 columns]

# %%
all_data.isnull().sum()
# Out:
# pizza        0
# burger       0
# sushi        0
# pasta        0
# isPartial    0
#             ..
# isPartial    0
# pepper       0
# olive oil    0
# vinegar      0
# isPartial    0
# Length: 84, dtype: int64

# %%
all_data.tail()
# Out:
#                      pizza  burger  sushi  pasta  isPartial  salad  steak  \
# date
# 2024-10-30 15:00:00     32      10     10     12      False     36     34
# 2024-10-30 16:00:00     38      12     11     14      False     42     37
# 2024-10-30 17:00:00     41      12     12     15      False     43     42
# 2024-10-30 18:00:00     41      12     12     15      False     42     42
# 2024-10-30 19:00:00     39      12     12     13       True     42     42
#
#                      tacos  sandwich  isPartial  ...  isPartial  fruits  \
# date                                             ...
# 2024-10-30 15:00:00     22        30      False  ...      False      25
# 2024-10-30 16:00:00     25        34      False  ...      False      25
# 2024-10-30 17:00:00     28        33      False  ...      False      23
# 2024-10-30 18:00:00     29        30      False  ...      False      23
# 2024-10-30 19:00:00     28        33       True  ...       True      21
#
#                      cereal  sugar  salt  isPartial  pepper  olive oil  \
# date
# 2024-10-30 15:00:00       7     71    48      False      61         19
# 2024-10-30 16:00:00       8     74    46      False      74         21
# 2024-10-30 17:00:00       8     79    51      False      77         21
# 2024-10-30 18:00:00       8     81    52      False      78         21
# 2024-10-30 19:00:00       9     80    55       True      82         28
#
#                      vinegar  isPartial
# date
# 2024-10-30 15:00:00       30      False
# 2024-10-30 16:00:00       34      False
# 2024-10-30 17:00:00       37      False
# 2024-10-30 18:00:00       35      False
# 2024-10-30 19:00:00       35       True
#
# [5 rows x 84 columns]

# %%
all_data = all_data.loc[:, ~all_data.columns.str.startswith('isPartial')]

# %%
all_data['total'] = all_data.sum(axis=1)
# Out:
# <ipython-input-9-16cf6c2396a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['total'] = all_data.sum(axis=1)

# %%
all_data.reset_index(drop=False, inplace=True)

# %%
all_data
# Out:
#                    date  pizza  burger  sushi  pasta  salad  steak  tacos  \
# 0   2024-10-23 19:00:00     35      11      9     11     41     43     26
# 1   2024-10-23 20:00:00     37      11     10     12     46     49     28
# 2   2024-10-23 21:00:00     52      12     12     14     56     69     35
# 3   2024-10-23 22:00:00     59      14     15     15     65     85     41
# 4   2024-10-23 23:00:00     54      14     14     14     60     89     43
# ..                  ...    ...     ...    ...    ...    ...    ...    ...
# 164 2024-10-30 15:00:00     32      10     10     12     36     34     22
# 165 2024-10-30 16:00:00     38      12     11     14     42     37     25
# 166 2024-10-30 17:00:00     41      12     12     15     43     42     28
# 167 2024-10-30 18:00:00     41      12     12     15     42     42     29
# 168 2024-10-30 19:00:00     39      12     12     13     42     42     28
#
#      sandwich  noodles  ...  pasta  vegetables  fruits  cereal  sugar  salt  \
# 0          29       47  ...     47           7      20       8     74    50
# 1          31       55  ...     51           7      22      10     77    53
# 2          35       69  ...     58           9      24      11     84    60
# 3          38       85  ...     61          10      26      11     91    65
# 4          37       83  ...     59          10      27      13     96    63
# ..        ...      ...  ...    ...         ...     ...     ...    ...   ...
# 164        30       44  ...     48           7      25       7     71    48
# 165        34       48  ...     58           7      25       8     74    46
# 166        33       50  ...     62           7      23       8     79    51
# 167        30       50  ...     60           8      23       8     81    52
# 168        33       50  ...     54           7      21       9     80    55
#
#      pepper  olive oil  vinegar  total
# 0        64         20       35   2071
# 1        72         23       40   2285
# 2        82         28       47   2658
# 3        89         33       54   2920
# 4        89         34       53   2877
# ..      ...        ...      ...    ...
# 164      61         19       30   1991
# 165      74         21       34   2187
# 166      77         21       37   2300
# 167      78         21       35   2262
# 168      82         28       35   2273
#
# [169 rows x 69 columns]

# %%
import matplotlib.pyplot as plt

# %%
all_data['hour'] = all_data['date'].dt.hour

plt.figure(figsize=(8, 5))
plt.plot(all_data['hour'], all_data['total'], marker='o', color='blue', label='Total')
plt.title('Total Value Distribution by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Total')
plt.axhline(y=all_data['total'].mean(), color='red', linestyle='--', label='Mean Total')
plt.legend()
plt.grid()
plt.xticks(all_data['hour'])
plt.show()

# %%
all_data.to_csv('all_data_oct_30.csv', index=False)
